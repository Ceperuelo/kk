# %% [markdown]
# <a href="https://colab.research.google.com/github/Ceperuelo/kk/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Un titulo 1<h1>
# <h2>Un titulo 2<h2>
# <h6>Un titulo 6<h6>
#
# # Otro titulo 1
# ## Otro titulo 2
# ###### Otro titulo 6

# %%
a = 1

# %%
b=8

# %%
c=a+b
c
# Out:
# 10

# %%
a=2
